# %%
# シミュレーション結果のJSONを表示してみよう
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# JSON結果ファイルを開く
JSON_DATA = "TvL_20240802174024.json"

with open(JSON_DATA) as f:
    json_obj = json.load(f)

for key, val in json_obj.items():
    print(key)
# Out:
# date
# Talents
# TURN_10
# TURN_20
# TURN_30
# TURN_40
# TURN_50
# TURN_60
# TURN_70
# TURN_80
# TURN_90
# TURN_100

# %%
capital_100 = json_obj["TURN_100"]["Capital"]
print( capital_100[0 : 10] ) # 先頭10件を見てみる
# Out:
# [1.6665047870751646, 5.0, 1.25, 6.137321250717314, 10.0, 12.243518052519862, 2.2229044556700908, 33.983046901984395, 15.691532478197697, 7.4122276977513195]

# %%
for key, values in json_obj.items():
    if key.startswith('TURN_'):
        print(key)
        val = values["Capital"]
        print( "min={:.3f}, max={:.03f}, sum={:.03f}, mean={:.03f}".format( min(val), max(val), sum(val), sum(val)/len(val) ) )
        plt.hist(val, bins=36)
        plt.show()
# Out:
# TURN_10
# min=1.250, max=69.495, sum=10417.560, mean=10.418
# TURN_20
# min=0.312, max=183.201, sum=11364.979, mean=11.365
# TURN_30
# min=0.156, max=253.584, sum=13323.979, mean=13.324
# TURN_40
# min=0.039, max=907.320, sum=15690.537, mean=15.691
# TURN_50
# min=0.039, max=550.581, sum=16464.880, mean=16.465
# TURN_60
# min=0.020, max=550.581, sum=17079.812, mean=17.080
# TURN_70
# min=0.012, max=573.867, sum=18540.857, mean=18.541
# TURN_80
# min=0.002, max=952.056, sum=21503.412, mean=21.503
# TURN_90
# min=0.002, max=1669.331, sum=24489.096, mean=24.489
# TURN_100
# min=0.004, max=1669.331, sum=26094.353, mean=26.094

# %%
talents = json_obj["Talents"]
# print( talents[ 0 : 10 ] )

for key, values in json_obj.items():
    if key.startswith('TURN_'):
        print(key)
        val = values["Capital"]
        print( "min={:.3f}, max={:.03f}, sum={:.03f}, mean={:.03f}".format( min(val), max(val), sum(val), sum(val)/len(val) ) )
        plt.scatter( talents, val )
        plt.show()
# Out:
# TURN_10
# min=1.250, max=69.495, sum=10417.560, mean=10.418
# TURN_20
# min=0.312, max=183.201, sum=11364.979, mean=11.365
# TURN_30
# min=0.156, max=253.584, sum=13323.979, mean=13.324
# TURN_40
# min=0.039, max=907.320, sum=15690.537, mean=15.691
# TURN_50
# min=0.039, max=550.581, sum=16464.880, mean=16.465
# TURN_60
# min=0.020, max=550.581, sum=17079.812, mean=17.080
# TURN_70
# min=0.012, max=573.867, sum=18540.857, mean=18.541
# TURN_80
# min=0.002, max=952.056, sum=21503.412, mean=21.503
# TURN_90
# min=0.002, max=1669.331, sum=24489.096, mean=24.489
# TURN_100
# min=0.004, max=1669.331, sum=26094.353, mean=26.094

# %%
for key, values in json_obj.items():
    if key.startswith('TURN_'):
        print(key)
        lucky = values["Lucky"]
        val = values["Capital"]
        print( "min={:.3f}, max={:.03f}, sum={:.03f}, mean={:.03f}".format( min(val), max(val), sum(val), sum(val)/len(val) ) )
        plt.scatter( lucky, val )
        plt.show()
# Out:
# TURN_10
# min=1.250, max=69.495, sum=10417.560, mean=10.418
# TURN_20
# min=0.312, max=183.201, sum=11364.979, mean=11.365
# TURN_30
# min=0.156, max=253.584, sum=13323.979, mean=13.324
# TURN_40
# min=0.039, max=907.320, sum=15690.537, mean=15.691
# TURN_50
# min=0.039, max=550.581, sum=16464.880, mean=16.465
# TURN_60
# min=0.020, max=550.581, sum=17079.812, mean=17.080
# TURN_70
# min=0.012, max=573.867, sum=18540.857, mean=18.541
# TURN_80
# min=0.002, max=952.056, sum=21503.412, mean=21.503
# TURN_90
# min=0.002, max=1669.331, sum=24489.096, mean=24.489
# TURN_100
# min=0.004, max=1669.331, sum=26094.353, mean=26.094

# %%
for key, values in json_obj.items():
    if key.startswith('TURN_'):
        print(key)
        unlucky = values["Unlucky"]
        val = values["Capital"]
        print( "min={:.3f}, max={:.03f}, sum={:.03f}, mean={:.03f}".format( min(val), max(val), sum(val), sum(val)/len(val) ) )
        plt.scatter( unlucky, val )
        plt.show()
# Out:
# TURN_10
# min=1.250, max=69.495, sum=10417.560, mean=10.418
# TURN_20
# min=0.312, max=183.201, sum=11364.979, mean=11.365
# TURN_30
# min=0.156, max=253.584, sum=13323.979, mean=13.324
# TURN_40
# min=0.039, max=907.320, sum=15690.537, mean=15.691
# TURN_50
# min=0.039, max=550.581, sum=16464.880, mean=16.465
# TURN_60
# min=0.020, max=550.581, sum=17079.812, mean=17.080
# TURN_70
# min=0.012, max=573.867, sum=18540.857, mean=18.541
# TURN_80
# min=0.002, max=952.056, sum=21503.412, mean=21.503
# TURN_90
# min=0.002, max=1669.331, sum=24489.096, mean=24.489
# TURN_100
# min=0.004, max=1669.331, sum=26094.353, mean=26.094

# %%
for key, values in json_obj.items():
    if key.startswith('TURN_'):
        print(key)
        lucky = np.array(values["Lucky"])
        unlucky = np.array(values["Unlucky"])
        luck_val = lucky - unlucky
        val = values["Capital"]
        print( "min={:.3f}, max={:.03f}, sum={:.03f}, mean={:.03f}".format( min(val), max(val), sum(val), sum(val)/len(val) ) )
        plt.scatter( luck_val, val )
        plt.show()
# Out:
# TURN_10
# min=1.250, max=69.495, sum=10417.560, mean=10.418
# TURN_20
# min=0.312, max=183.201, sum=11364.979, mean=11.365
# TURN_30
# min=0.156, max=253.584, sum=13323.979, mean=13.324
# TURN_40
# min=0.039, max=907.320, sum=15690.537, mean=15.691
# TURN_50
# min=0.039, max=550.581, sum=16464.880, mean=16.465
# TURN_60
# min=0.020, max=550.581, sum=17079.812, mean=17.080
# TURN_70
# min=0.012, max=573.867, sum=18540.857, mean=18.541
# TURN_80
# min=0.002, max=952.056, sum=21503.412, mean=21.503
# TURN_90
# min=0.002, max=1669.331, sum=24489.096, mean=24.489
# TURN_100
# min=0.004, max=1669.331, sum=26094.353, mean=26.094
